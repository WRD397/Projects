# %% [markdown]
# ## Predicting the Mode of transport

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
#pd.set_option('max_columns', None)

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv('E:\GitHub_Repos\Projects\SupplyChainModePrediction\SCMS_Delivery_History_Dataset.csv')
data.head(5)
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# 1                        240               1000          6200.0       6.20
# 2                        100                500         40000.0      80.00
# 3                         60              31920        127360.8       3.99
# 4                         60              38000        121600.0       3.20
#
#   Unit Price             Manufacturing Site First Line Designation  \
# 0       0.97     Ranbaxy Fine Chemicals LTD                    Yes
# 1       0.03      Aurobindo Unit III, India                    Yes
# 2       0.80  ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 3       0.07  Ranbaxy, Paonta Shahib, India                    Yes
# 4       0.05      Aurobindo Unit III, India                    Yes
#
#   Weight (Kilograms) Freight Cost (USD) Line Item Insurance (USD)
# 0                 13             780.34                       NaN
# 1                358             4521.5                       NaN
# 2                171            1653.78                       NaN
# 3               1855           16007.06                       NaN
# 4               7590           45450.08                       NaN
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
#  12  Scheduled Delivery Date       10324 non-null  object
#  13  Delivered to Client Date      10324 non-null  object
#  14  Delivery Recorded Date        10324 non-null  object
#  15  Product Group                 10324 non-null  object
#  16  Sub Classification            10324 non-null  object
#  17  Vendor                        10324 non-null  object
#  18  Item Description              10324 non-null  object
#  19  Molecule/Test Type            10324 non-null  object
#  20  Brand                         10324 non-null  object
#  21  Dosage                        8588 non-null   object
#  22  Dosage Form                   10324 non-null  object
#  23  Unit of Measure (Per Pack)    10324 non-null  int64
#  24  Line Item Quantity            10324 non-null  int64
#  25  Line Item Value               10324 non-null  float64
#  26  Pack Price                    10324 non-null  float64
#  27  Unit Price                    10324 non-null  float64
#  28  Manufacturing Site            10324 non-null  object
#  29  First Line Designation        10324 non-null  object
#  30  Weight (Kilograms)            10324 non-null  object
#  31  Freight Cost (USD)            10324 non-null  object
#  32  Line Item Insurance (USD)     10037 non-null  float64
# dtypes: float64(4), int64(3), object(26)
# memory usage: 2.6+ MB

# %% [markdown]
# Missing Values

# %%
data.isna().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# Line Item Value                    0
# Pack Price                         0
# Unit Price                         0
# Manufacturing Site                 0
# First Line Designation             0
# Weight (Kilograms)                 0
# Freight Cost (USD)                 0
# Line Item Insurance (USD)        287
# dtype: int64

# %% [markdown]
# Also to get the percentage of the missing values, lets return the means of the columns

# %%
data.isna().mean()
# Out:
# ID                              0.000000
# Project Code                    0.000000
# PQ #                            0.000000
# PO / SO #                       0.000000
# ASN/DN #                        0.000000
# Country                         0.000000
# Managed By                      0.000000
# Fulfill Via                     0.000000
# Vendor INCO Term                0.000000
# Shipment Mode                   0.034870
# PQ First Sent to Client Date    0.000000
# PO Sent to Vendor Date          0.000000
# Scheduled Delivery Date         0.000000
# Delivered to Client Date        0.000000
# Delivery Recorded Date          0.000000
# Product Group                   0.000000
# Sub Classification              0.000000
# Vendor                          0.000000
# Item Description                0.000000
# Molecule/Test Type              0.000000
# Brand                           0.000000
# Dosage                          0.168152
# Dosage Form                     0.000000
# Unit of Measure (Per Pack)      0.000000
# Line Item Quantity              0.000000
# Line Item Value                 0.000000
# Pack Price                      0.000000
# Unit Price                      0.000000
# Manufacturing Site              0.000000
# First Line Designation          0.000000
# Weight (Kilograms)              0.000000
# Freight Cost (USD)              0.000000
# Line Item Insurance (USD)       0.027799
# dtype: float64

# %% [markdown]
# Shipment Modes, Dosage and Line Item Insurance have missing values in them. Now, here our target column also contains missing values and we dont wanna fill the model with missing rows while training. So we are gonna drop the rows containing missing values for atleast the training dataset.

# %%
df = data.copy()
    # As ID column is not gonna add any value to the model we are gonna build, so lets drop the ID column.
df = df.drop('ID', axis=1)
df_missing = df['Shipment Mode'].isna()

# %%
condition = df['Shipment Mode'].isnull()
df_missing_targets = df[condition]
df_missing_targets.head()
# Out:
#    Project Code            PQ #   PO / SO #  ASN/DN #       Country  \
# 16   102-NG-T01  Pre-PQ Process    SCMS-354   ASN-608       Nigeria
# 31   116-ZA-T01  Pre-PQ Process  SCMS-14050  ASN-1251  South Africa
# 36   116-ZA-T01  Pre-PQ Process  SCMS-16600  ASN-1520  South Africa
# 42   117-ET-T01  Pre-PQ Process  SCMS-18430  ASN-1465      Ethiopia
# 50   116-ZA-T01  Pre-PQ Process  SCMS-21460  ASN-1667  South Africa
#
#    Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 16   PMO - US  Direct Drop              CIP           NaN
# 31   PMO - US  Direct Drop              DDP           NaN
# 36   PMO - US  Direct Drop              DDP           NaN
# 42   PMO - US  Direct Drop              DDP           NaN
# 50   PMO - US  Direct Drop              DDP           NaN
#
#    PQ First Sent to Client Date  ... Unit of Measure (Per Pack)  \
# 16               Pre-PQ Process  ...                        100
# 31               Pre-PQ Process  ...                        200
# 36               Pre-PQ Process  ...                        200
# 42               Pre-PQ Process  ...                        100
# 50               Pre-PQ Process  ...                         60
#
#    Line Item Quantity Line Item Value Pack Price Unit Price  \
# 16               1500       120000.00      80.00       0.80
# 31                 40          317.60       7.94       0.04
# 36                200          340.00       1.70       0.01
# 42                 63        13399.25     212.69       2.13
# 50                  6           77.10      12.85       0.21
#
#                Manufacturing Site First Line Designation  \
# 16  ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 31       GSK Mississauga (Canada)                    Yes
# 36             BMS Meymac, France                    Yes
# 42           Trinity Biotech, Plc                    Yes
# 50             BMS Meymac, France                    Yes
#
#             Weight (Kilograms)                  Freight Cost (USD)  \
# 16  Weight Captured Separately  Freight Included in Commodity Cost
# 31  Weight Captured Separately  Freight Included in Commodity Cost
# 36  Weight Captured Separately  Freight Included in Commodity Cost
# 42  Weight Captured Separately  Freight Included in Commodity Cost
# 50  Weight Captured Separately  Freight Included in Commodity Cost
#
#    Line Item Insurance (USD)
# 16                    192.00
# 31                      0.51
# 36                      0.54
# 42                     21.44
# 50                      0.12
#
# [5 rows x 32 columns]

# %% [markdown]
# We are gonna preserve the data to concat this with our test dataset. Now lets prepare the train data.

# %%
df_missing_targets_index =df_missing_targets.index
df_missing_targets_index
# Out:
# Int64Index([  16,   31,   36,   42,   50,  157,  158,  165,  186,  187,
#             ...
#             2526, 2527, 2528, 2529, 2530, 2539, 2552, 2561, 2574, 2610],
#            dtype='int64', length=360)

# %%
df = df.drop(df_missing_targets_index, axis=0).reset_index(drop=True)

# %% [markdown]
# Now, Lets fill the missing values for 'dosage' and 'line items insurance' columns.<br>
# Now, as the dosage column contains different values from a huge range. So it does not make much sense to fill up the missing values with mean. So, kets try to fill up with the most occurence values.

# %%
len(df['Dosage'].unique())
# Out:
# 55

# %% [markdown]
# So, there are 55 unique values among 9244 rows. So, it will be better to fill the missing values with the most occurence values.

# %%
df.Dosage = df.Dosage.fillna(df.Dosage.mode()[0]) ##in case we got multiple modes, so we are using first mode value to fill the columns.
df.isna().sum()
# Out:
# Project Code                      0
# PQ #                              0
# PO / SO #                         0
# ASN/DN #                          0
# Country                           0
# Managed By                        0
# Fulfill Via                       0
# Vendor INCO Term                  0
# Shipment Mode                     0
# PQ First Sent to Client Date      0
# PO Sent to Vendor Date            0
# Scheduled Delivery Date           0
# Delivered to Client Date          0
# Delivery Recorded Date            0
# Product Group                     0
# Sub Classification                0
# Vendor                            0
# Item Description                  0
# Molecule/Test Type                0
# Brand                             0
# Dosage                            0
# Dosage Form                       0
# Unit of Measure (Per Pack)        0
# Line Item Quantity                0
# Line Item Value                   0
# Pack Price                        0
# Unit Price                        0
# Manufacturing Site                0
# First Line Designation            0
# Weight (Kilograms)                0
# Freight Cost (USD)                0
# Line Item Insurance (USD)       181
# dtype: int64

# %% [markdown]
# Now, lets fill the Line Item Insurance column values with mean value of the column.

# %%
df['Line Item Insurance (USD)'] = df['Line Item Insurance (USD)'].fillna(df['Line Item Insurance (USD)'].mean())

# %% [markdown]
# ## Encoding

# %% [markdown]
# Lets look at all the object type columns which need to be encoded before feeding into a neural network.

# %%
df.select_dtypes('object').columns
# Out:
# Index(['Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Manufacturing Site', 'First Line Designation',
#        'Weight (Kilograms)', 'Freight Cost (USD)'],
#       dtype='object')

# %% [markdown]
# First lets look at the date columns.

# %%
date_features = [
    'PQ First Sent to Client Date',
    'PO Sent to Vendor Date',
    'Scheduled Delivery Date',
    'Delivered to Client Date',
    'Delivery Recorded Date'
]
for column in date_features:
    print(column, pd.to_datetime(df[column], errors='coerce').isna().sum())
# Out:
# PQ First Sent to Client Date 2321
# PO Sent to Vendor Date 5417
# Scheduled Delivery Date 0
# Delivered to Client Date 0
# Delivery Recorded Date 0
